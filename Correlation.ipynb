# %%
from google.colab import files
#To allow access to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
data1 = pd.read_csv('/content/drive/MyDrive/NSCI0028 Project/Dataset.csv')
print(data1)
print(data1.corr())
dataplot = sns.heatmap(data1.corr())
plt.show

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data2 = np.genfromtxt('/content/drive/MyDrive/NSCI0028 Project/Dataset.csv',delimiter = ",")
df = pd.DataFrame(data=data2, columns=["Electrical Potential", "Powder Feed Pressure","Working Distance"])
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show>
